# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_pickle('../data/processed/processed_df.pickle')

# %% [markdown]
# ## <center> Univariate Analysis </center>

# %%
sns.distplot(df['age']).set_title('Distribution of age');

# %%
sns.countplot(df['sex']).set_title('Counts of sex');

# %%
sns.countplot(df['cp']).set_title('Counts of cp');

# %%
sns.distplot(df['chol']).set_title('Distribution of chol');

# %%
sns.countplot(df['fbs']).set_title('Counts of fbs');

# %%
sns.countplot(df['restecg']).set_title('Counts of restecg');

# %%
sns.distplot(df['thalach']).set_title('Distribution of thalach');

# %%
sns.countplot(df['exang']).set_title('Counts of exang');

# %%
sns.distplot(df['oldpeak']).set_title('Distribution of oldpeak');

# %%
sns.countplot(df['slope']).set_title('Counts of slope');

# %%
sns.countplot(df['ca']).set_title('Counts of ca');

# %%
sns.countplot(df['thal']).set_title('Counts of thal');

# %%
sns.countplot(df['num']).set_title('Counts of num');

# %% [markdown]
# ## <center> Bivariate Analysis </center>

# %%
sns.boxplot(x=df['num'], y=df['age']).set_title('Num vs Age Boxplot');

# %%
sns.factorplot(x='num', col='sex', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Sex Barplot');

# %%
sns.factorplot(x='num', col='cp', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Cp Barplot');

# %%
sns.boxplot(x=df['num'], y=df['chol']).set_title('Num vs Chol Boxplot');

# %%
sns.factorplot(x='num', col='fbs', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Fbs Barplot');

# %%
sns.factorplot(x='num', col='restecg', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Restecg Barplot');

# %%
sns.boxplot(x=df['num'], y=df['thalach']).set_title('Num vs Thalach Boxplot');

# %%
sns.factorplot(x='num', col='exang', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Exang Barplot');

# %%
sns.boxplot(x=df['num'], y=df['oldpeak']).set_title('Num vs Oldpeak Boxplot');

# %%
sns.factorplot(x='num', col='slope', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Slope Barplot');

# %%
sns.factorplot(x='num', col='ca', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Ca Barplot');

# %%
sns.factorplot(x='num', col='thal', data=df, kind='count', size=4, aspect=.7);
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Num vs Thal Barplot');

# %% [markdown]
# #
